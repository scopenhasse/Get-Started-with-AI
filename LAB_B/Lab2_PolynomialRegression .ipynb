# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# What if your data doesn't look linear at all? Let's look at some more realistic-looking page speed / purchase data:

# %%
# %matplotlib inline
from pylab import *
import numpy as np

np.random.seed(2)
pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = np.random.normal(50.0, 10.0, 1000) / pageSpeeds

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# numpy has a handy polyfit function we can use, to let us construct an nth-degree polynomial model of our data that minimizes squared error. Let's try it with a 4th degree polynomial:

# %%
x = np.array(pageSpeeds)
y = np.array(purchaseAmount)

p4 = np.poly1d(np.polyfit(x, y, 4))

# polyfit returns the coefficients of the polynomial in descending order of power (i.e. highest power first)
# so we need to reverse the array to get the coefficients in ascending order of power 
# poly1d takes the coefficients in ascending order of power

# %% [markdown]
# We'll visualize our original scatter plot, together with a plot of our predicted values using the polynomial for page speed times ranging from 0-7 seconds:

# %%
import matplotlib.pyplot as plt

xp = np.linspace(0, 7)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %% [markdown]
# Measure the r-squared error :

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y, p4(x))

print(r2)
# Out:
# 0.8293766396303073

# %% [markdown]
# ## Activity

# %% [markdown]
# Try different polynomial orders smaller and bigger than 4. Can you get a better fit with higher orders? What are your comments on the shape of the plot and the R-sqruared measure?

# %%
# trying with 2nd degree polynomial to see the diffrence 
p2 = np.poly1d(np.polyfit(x, y, 2))

xp = np.linspace(0, 7)
plt.scatter(x, y)
plt.plot(xp, p2(xp), c='g')
plt.show()

from sklearn.metrics import r2_score
r2 = r2_score(y, p2(x))
print(r2)
# Out:
# 0.6927446350535892

# %%
# trying with 8th degree polynomial to see the diffrence 
p8 = np.poly1d(np.polyfit(x, y, 8))

xp = np.linspace(0, 7)
plt.scatter(x, y)
plt.plot(xp, p8(xp), c='g')
plt.show()

from sklearn.metrics import r2_score
r8 = r2_score(y, p8(x))
print(r8)
# Out:
# 0.8814395663681561

# %%
# trying with 16th degree polynomial to see the diffrence 
p16 = np.poly1d(np.polyfit(x, y, 16))

xp = np.linspace(0, 7)
plt.scatter(x, y)
plt.plot(xp, p16(xp), c='g')
plt.show()

from sklearn.metrics import r2_score
r16 = r2_score(y, p16(x))
print(r16)
# Out:
# 0.884860137885524

# %%
# as the degree of the polynomial increases the r2 score 
# increases but the model becomes more complex and overfits the data
