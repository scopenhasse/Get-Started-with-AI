# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 49.90871339684705

# %%
incomes.var()
# Out:
# 2490.87967292862

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
incomes = np.random.normal(120.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
print("Deviation",incomes.std())
print("Variance",incomes.var())
# Out:
# Deviation 49.62101332984833
# Variance 2462.244963880986

# %%
incomes = np.random.normal(100.0, 500.0, 1000000)

plt.hist(incomes, 50)
plt.show()

# %%
print("Deviation",incomes.std())
print("Variance",incomes.var())
# Out:
# Deviation 499.8792854931154
# Variance 249879.30006510756
